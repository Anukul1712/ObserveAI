# %%
import sys
import os
from pathlib import Path

# Add project root to path
project_root = Path(os.getcwd()).parent.parent
sys.path.append(str(project_root))

print(f"Project root added: {project_root}")
# Out:
# Project root added: d:\DEV\Python\interiit25\Observe\observe_ai

# %% [markdown]
# ## 1. Test GraphStore
# Tests connection to Neo4j and intent retrieval.

# %%
from src.rag.graph_store import GraphStore

graph_store = GraphStore()
print("GraphStore initialized successfully.")

# Test getting related intents for a known intent (e.g., 'Dispute_Charge' or something from your taxonomy)
# You might need to check your taxonomy.json or Neo4j DB for a valid intent name first.
test_intent = "Dispute_Charge" 
related = graph_store.get_related_intents(test_intent)
print(f"Related intents for '{test_intent}':")
print(related)

graph_store.close()
# Out:
# 2025-12-02 18:51:39,298 - src.rag.graph_store - INFO - Connected to Neo4j GraphStore.
# GraphStore initialized successfully.
# Related intents for 'Dispute_Charge':
# {'Process_Refund': 1.0, 'Explain_Charge': 0.8365758754863813, 'Verify_Identity': 0.5849546044098574, 'Provide_Promo_Codes': 0.3424124513618677, 'Investigate_Billing_Issue': 0.26718547341115434, 'Dispute_Charge': 1.0}

# %% [markdown]
# ## 2. Test QueryClassifier
# Tests LLM-based classification of queries.

# %%
from src.rag.query_classifier import QueryClassifier

try:
    classifier = QueryClassifier()
    print("QueryClassifier initialized.")
    
    test_query = "I want to dispute a charge on my bill."
    intent = classifier.classify(test_query)
    print(f"Query: '{test_query}'")
    print(f"Classified Intent: {intent}")
    
    test_query_2 = "Why is my internet so slow?"
    intent_2 = classifier.classify(test_query_2)
    print(f"Query: '{test_query_2}'")
    print(f"Classified Intent: {intent_2}")
    
except Exception as e:
    print(f"QueryClassifier Test Failed: {e}")
# Out:
# QueryClassifier initialized.
# Query: 'I want to dispute a charge on my bill.'
# Classified Intent: Dispute_Charge
# Query: 'I want to dispute a charge on my bill.'
# Classified Intent: Dispute_Charge
# Query: 'Why is my internet so slow?'
# Classified Intent: Diagnose_Technical_Issues
# Query: 'Why is my internet so slow?'
# Classified Intent: Diagnose_Technical_Issues

# %% [markdown]
# ## 3. Test Retriever (Dual Retrieval)
# Tests the full retrieval pipeline.

# %%
from src.rag.retriever import Retriever
from src.rag.embeddings import EmbeddingModel
from src.rag.vector_store import VectorStore
from src.rag.graph_store import GraphStore
from src.rag.transcript_store import TranscriptStore
from sentence_transformers import CrossEncoder
from src.config import Config

reranker = CrossEncoder(Config.RERANKER_MODEL)
embedding_model = EmbeddingModel()
vector_store = VectorStore()
graph_store = GraphStore()
transcript_store = TranscriptStore()

# Use the custom Retriever class
retriever = Retriever(
    embedding_model=embedding_model,
    vector_store=vector_store,
    graph_store=graph_store,
    transcript_store=transcript_store,
    reranker=reranker
)
print("Retriever initialized.")
# Out:
# 2025-12-04 18:01:24,970 - sentence_transformers.cross_encoder.CrossEncoder - INFO - Use pytorch device: cpu
# 2025-12-04 18:01:26,929 - src.rag.embeddings - INFO - Loading embedding model: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-04 18:01:26,929 - src.rag.embeddings - INFO - Using device: cpu
# 2025-12-04 18:01:26,929 - sentence_transformers.SentenceTransformer - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-04 18:01:26,929 - src.rag.embeddings - INFO - Loading embedding model: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-04 18:01:26,929 - src.rag.embeddings - INFO - Using device: cpu
# 2025-12-04 18:01:26,929 - sentence_transformers.SentenceTransformer - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-04 18:01:32,307 - src.rag.embeddings - INFO - Initialized embedding model: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-04 18:01:32,322 - src.rag.embeddings - INFO - Loading embedding model: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-04 18:01:32,323 - src.rag.embeddings - INFO - Using device: cpu
# 2025-12-04 18:01:32,329 - sentence_transformers.SentenceTransformer - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-04 18:01:32,307 - src.rag.embeddings - INFO - Initialized embedding model: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-04 18:01:32,322 - src.rag.embeddings - INFO - Loading embedding model: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-04 18:01:32,323 - src.rag.embeddings - INFO - Using device: cpu
# 2025-12-04 18:01:32,329 - sentence_transformers.SentenceTransformer - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-04 18:01:36,374 - src.rag.embeddings - INFO - Initialized embedding model: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-04 18:01:36,375 - src.rag.vector_store - INFO - Initializing Chroma vector store at: d:\DEV\Python\interiit25\Observe\observe_ai\data\vector_db
# 2025-12-04 18:01:36,374 - src.rag.embeddings - INFO - Initialized embedding model: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-04 18:01:36,375 - src.rag.vector_store - INFO - Initializing Chroma vector store at: d:\DEV\Python\interiit25\Observe\observe_ai\data\vector_db
# 2025-12-04 18:01:36,619 - chromadb.telemetry.product.posthog - INFO - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2025-12-04 18:01:36,619 - chromadb.telemetry.product.posthog - INFO - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2025-12-04 18:05:45,640 - src.rag.vector_store - INFO - Vector store initialized. Collection 'rag_collection'
# Loaded with 681979 items.
# 2025-12-04 18:05:45,640 - src.rag.vector_store - INFO - Vector store initialized. Collection 'rag_collection'
# Loaded with 681979 items.
# 2025-12-04 18:05:47,742 - src.rag.graph_store - INFO - Connected to Neo4j GraphStore.
# 2025-12-04 18:05:47,742 - src.rag.transcript_store - INFO - Loading transcripts from d:\DEV\Python\interiit25\Observe\observe_ai\data\labelled_transcript_allMiniLM_2.json...
# 2025-12-04 18:05:47,742 - src.rag.graph_store - INFO - Connected to Neo4j GraphStore.
# 2025-12-04 18:05:47,742 - src.rag.transcript_store - INFO - Loading transcripts from d:\DEV\Python\interiit25\Observe\observe_ai\data\labelled_transcript_allMiniLM_2.json...
# 2025-12-04 18:05:51,227 - src.rag.transcript_store - INFO - Loaded 19615 transcripts into memory.
# 2025-12-04 18:05:51,227 - src.rag.transcript_store - INFO - Loaded 19615 transcripts into memory.
# Retriever initialized.

# %%
# import importlib
# import src.rag.retriever as retriever_module

# importlib.reload(retriever_module)

# from src.rag.retriever import Retriever
# retriever = Retriever(
#     embedding_model=embedding_model,
#     vector_store=vector_store,
#     graph_store=graph_store,
#     transcript_store=transcript_store
# )

# %%
query = "Reason for refund rejection"
results = retriever.retrieve_dual(query)
# Out:
# 2025-12-04 18:05:59,949 - src.rag.retriever - INFO - Reranking 50 candidates...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
len(results)
# Out:
# 10

# %%
results
# Out:
# [RetrievalResult(transcript_id='2f7d2a66-c447-4cbd-b76c-e61f297d3004', turn_index=11, content=['Agent: thanks for holding i have your account here uh you called about the refund related to um the billing error is that correct', "Customer: yes that's it there was um a mistake i need help with", "Agent: alright so i see a transaction on your account with reference txn 987654321 it appears that the refund request was denied based on the um shouldn't be evadence evidence", 'Customer: denied but i thought it would be processed more quickly um what was the reason', "Agent: the merchant provided documentation showing that the charge was valid so unfortunately we couldn't issue a refund", "Customer: that's really frustrating i had been counting on that money other banks like um bank of america seem to handle disputes um way faster", 'Agent: i understand your frustration um ahh and i apologize for the inconvenience civic trust has strict policies to ensure transparency in these situations'], metadata={'time_of_interaction': '2025-11-06 15:31:00', 'turn_index': 11, 'speaker': 'Customer', 'secondary_intent': 'Report_Suspected_Fraud', 'turn_id': '2f7d2a66-c447-4cbd-b76c-e61f297d3004_11', 'global_intent': 'Refund Delays', 'transcript_id': '2f7d2a66-c447-4cbd-b76c-e61f297d3004', 'primary_intent': 'Fraud_Reporting', 'type': 'turn_with_context', 'domain': 'Insurance', 'reason_for_call': 'The customer called to dispute a refund delay, seeking clarification on the refund outcome and processing times.'}, score=0.4685198664665222, graph_score=0.0, semantic_score=0.0, final_score=0.0, intent='Report_Suspected_Fraud'),
#  RetrievalResult(transcript_id='dcefeb1e-eae2-4dbe-a081-624848fa764b', turn_index=13, content=["Agent: i understand your frustration david the um exceptions they can vary you know by claim let's see how they apply to yours", 'Customer: right and um will i be eligible for a refund', "Agent: refunds depend on several factors including um the reasons for the claim denial it's a bit complicated", "Customer: but you see i need to know if there's any um way to appeal this", 'Agent: yes you certainly can appeal if you um provide more information we can uh review the decision', 'Customer: like what information i mean um what are the next steps here', "Agent: you'll need to submit any additional documents that might support your case and um we will revisit your claim"], metadata={'type': 'turn_with_context', 'global_intent': 'Claims & refunds', 'transcript_id': 'dcefeb1e-eae2-4dbe-a081-624848fa764b', 'reason_for_call': 'Customer called seeking clarification on a denied life insurance claim and inquired about refund eligibility.', 'time_of_interaction': '2025-11-10 12:55:00', 'speaker': 'Customer', 'turn_id': 'dcefeb1e-eae2-4dbe-a081-624848fa764b_13', 'secondary_intent': 'Request_Resolution', 'primary_intent': 'Hotel_Complaint', 'turn_index': 13, 'domain': 'Insurance'}, score=0.3942568898200989, graph_score=0.0, semantic_score=0.0, final_score=0.0, intent='Request_Resolution'),
#  RetrievalResult(transcript_id='3c3ca280-3d61-43cf-a51e-3f60d3275902', turn_index=7, content=["Agent: thank you zoey um let me pull that up can you also remind me which uh transaction you're inquiring about", "Customer: yeah it's for txn 145698732 i um i was promised the refund would be processed last month", 'Agent: okay let me check *pauses* it seems that the refund was uhh denied uhh due to a service issue with your claim', 'Customer: denied why i was told everything looked good everything looked good when i submitted the claim', "Agent: i understand your frustration zoey the terms of your policy uh state that refunds can can be denied based on let's see merchant evidence provided", "Customer: but that doesn't doesn't make sense the merchant confirmed everything ugh this is impacting my finances", 'Agent: i can imagine that this is tough the delay has certainly been um longer than anticipated and i apologize for that'], metadata={'turn_id': '3c3ca280-3d61-43cf-a51e-3f60d3275902_7', 'global_intent': 'Refund Delays', 'turn_index': 7, 'secondary_intent': 'Dispute_Charge', 'type': 'turn_with_context', 'reason_for_call': 'Customer Zoey Reed called about a delayed refund decision related to her insurance claim.', 'speaker': 'Customer', 'primary_intent': 'Billing & Refunds', 'transcript_id': '3c3ca280-3d61-43cf-a51e-3f60d3275902', 'domain': 'Insurance', 'time_of_interaction': '2025-11-08 11:13:00'}, score=0.34395700693130493, graph_score=0.0, semantic_score=0.0, final_score=0.0, intent='Dispute_Charge'),
#  RetrievalResult(transcript_id='2f7d2a66-c447-4cbd-b76c-e61f297d3004', turn_index=10, content=['Customer: okay sure', 'Agent: thanks for holding i have your account here uh you called about the refund related to um the billing error is that correct', "Customer: yes that's it there was um a mistake i need help with", "Agent: alright so i see a transaction on your account with reference txn 987654321 it appears that the refund request was denied based on the um shouldn't be evadence evidence", 'Customer: denied but i thought it would be processed more quickly um what was the reason', "Agent: the merchant provided documentation showing that the charge was valid so unfortunately we couldn't issue a refund", "Customer: that's really frustrating i had been counting on that money other banks like um bank of america seem to handle disputes um way faster"], metadata={'speaker': 'Agent', 'global_intent': 'Refund Delays', 'primary_intent': 'Billing & Refunds', 'turn_index': 10, 'secondary_intent': 'Investigate_Billing_Issue', 'time_of_interaction': '2025-11-06 15:31:00', 'domain': 'Insurance', 'turn_id': '2f7d2a66-c447-4cbd-b76c-e61f297d3004_10', 'transcript_id': '2f7d2a66-c447-4cbd-b76c-e61f297d3004', 'reason_for_call': 'The customer called to dispute a refund delay, seeking clarification on the refund outcome and processing times.', 'type': 'turn_with_context'}, score=-0.08514511585235596, graph_score=0.0, semantic_score=0.0, final_score=0.0, intent='Investigate_Billing_Issue'),
#  RetrievalResult(transcript_id='ef42a9a5-e5c9-4dfa-b811-6e12525fd96f', turn_index=17, content=["Agent: right i'm checking the notes here it says that um there was some evidence from the merchant indicating the refund was denied", "Customer: denied really why wasn't i um informed about that sooner", "Agent: it appears the denial was due to a lack of confirmation from the service provider um that's how the policy works", "Customer: so you're saying i won't get my money back that's really frustrating", "Agent: i can see why you're upset unfortunately without adequate evidence um supporting your dispute the refund can't be processed", "Customer: but don't you think probing questions could help clarify this situation", "Agent: honestly we didn't ask probing questions in this case so it's likely yeah those could have led to a clearer outcome"], metadata={'turn_index': 17, 'global_intent': 'Refund Delays', 'domain': 'Insurance', 'speaker': 'Customer', 'reason_for_call': 'Ava called to resolve an issue related to refund delays for a disputed transaction with FirstStone Bank.', 'turn_id': 'ef42a9a5-e5c9-4dfa-b811-6e12525fd96f_17', 'transcript_id': 'ef42a9a5-e5c9-4dfa-b811-6e12525fd96f', 'type': 'turn_with_context', 'primary_intent': 'Billing & Refunds', 'time_of_interaction': '2025-11-09 10:49:00', 'secondary_intent': 'Dispute_Charge'}, score=-0.26156193017959595, graph_score=0.0, semantic_score=0.0, final_score=0.0, intent='Dispute_Charge'),
#  RetrievalResult(transcript_id='5e247642-c0a4-45d2-a48b-de77614a9826', turn_index=20, content=["Customer: that's nice do you think like promotions like that really shift outcomes without offering discounts", 'Agent: yes they do as evidenced by uh increased customer satisfaction many find promotions um appealing even without discounts', "Customer: interesting and what happens if my refund gets denied i've heard that can lead to like dissatisfaction", 'Agent: yes a denial could trigger drop off and frustration definitely we strive to avoid those sort of situations', "Customer: right i just don't want to deal with that can you give me a summary of the uh policy around this", "Agent: sure if the item is returned within the specified period and is undamaged the refund will be processed without issues i'm pretty sure", "Customer: sounds fair and if i have more questions later what's the best way to reach uh out again"], metadata={'type': 'turn_with_context', 'reason_for_call': 'Gabriel Mitchell called to follow up on a refund for a returned product purchased from ShopSquare.', 'domain': 'Insurance', 'time_of_interaction': '2025-11-06 09:40:00', 'primary_intent': 'Cancellation_Policy', 'global_intent': 'Replacement vs Refund', 'secondary_intent': 'Explain_Cancellation_Policy', 'turn_index': 20, 'turn_id': '5e247642-c0a4-45d2-a48b-de77614a9826_20', 'transcript_id': '5e247642-c0a4-45d2-a48b-de77614a9826', 'speaker': 'Agent'}, score=-1.0646555423736572, graph_score=0.0, semantic_score=0.0, final_score=0.0, intent='Explain_Cancellation_Policy'),
#  RetrievalResult(transcript_id='43215223-03de-425b-bf13-d947af27673d', turn_index=17, content=["Agent: i completely get your point owen it's just that with this specific claim uh there were some eligibility criteria that unfortunately uh limited the total refund", "Customer: that sounds like a real letdown it's not um what i expected from civic trust", "Agent: i'm uh really sorry to hear that if you'd like i can go through the eligibility criteria with you", "Customer: sure please i'd like some clarity on that", "Agent: great so the reason for the partial refund is categorized under a service issue and um i can see you had some items that didn't qualify ugh", 'Customer: like what', 'Agent: the specific items were deemed ineligible um leading to uh the partial outcome'], metadata={'global_intent': 'Refund Delays', 'speaker': 'Customer', 'turn_id': '43215223-03de-425b-bf13-d947af27673d_17', 'type': 'turn_with_context', 'secondary_intent': 'Inquire_About_Policies', 'reason_for_call': 'Customer seeking clarification and resolution for a delayed refund where only a partial credit was issued.', 'transcript_id': '43215223-03de-425b-bf13-d947af27673d', 'time_of_interaction': '2025-11-07 09:43:00', 'primary_intent': 'Credit_Limit_Adjustment', 'turn_index': 17, 'domain': 'Insurance'}, score=-1.1104977130889893, graph_score=0.0, semantic_score=0.0, final_score=0.0, intent='Inquire_About_Policies'),
#  RetrievalResult(transcript_id='529dd14b-1163-4c10-8e32-d481fa4cbf3e', turn_index=9, content=['Agent: i completely understand your frustration uh just a sec while i check the details on the refund process for this', "Customer: i called last week and y'know they said it was being processed what's the hold up", 'Agent: right i see that the refund was um actually denied due to our policy guidelines', 'Customer: denied wait um what do you mean', "Agent: yes i'm sorry the denial was based on the specific um service issue uh related to your claim there's a specific guideline that applies here", "Customer: so you're saying there's nothing that can be done this is so frustrating", "Agent: i definitely can see why you feel that way samuel it's um really not easy when these things happen"], metadata={'type': 'turn_with_context', 'speaker': 'Customer', 'reason_for_call': 'Customer Samuel Rivera called to inquire about a refund delay on a disputed transaction with Metro Capital.', 'turn_index': 9, 'transcript_id': '529dd14b-1163-4c10-8e32-d481fa4cbf3e', 'global_intent': 'Refund Delays', 'domain': 'Insurance', 'time_of_interaction': '2025-11-10 10:27:00', 'primary_intent': 'General_Conversation', 'secondary_intent': 'Ask_for_Clarification', 'turn_id': '529dd14b-1163-4c10-8e32-d481fa4cbf3e_9'}, score=-1.2207027673721313, graph_score=0.0, semantic_score=0.0, final_score=0.0, intent='Ask_for_Clarification'),
#  RetrievalResult(transcript_id='dcefeb1e-eae2-4dbe-a081-624848fa764b', turn_index=12, content=["Customer: okay because i uh thought i understood everything but now i'm confused", "Agent: i understand your frustration david the um exceptions they can vary you know by claim let's see how they apply to yours", 'Customer: right and um will i be eligible for a refund', "Agent: refunds depend on several factors including um the reasons for the claim denial it's a bit complicated", "Customer: but you see i need to know if there's any um way to appeal this", 'Agent: yes you certainly can appeal if you um provide more information we can uh review the decision', 'Customer: like what information i mean um what are the next steps here'], metadata={'domain': 'Insurance', 'primary_intent': 'Billing & Refunds', 'global_intent': 'Claims & refunds', 'type': 'turn_with_context', 'turn_id': 'dcefeb1e-eae2-4dbe-a081-624848fa764b_12', 'transcript_id': 'dcefeb1e-eae2-4dbe-a081-624848fa764b', 'secondary_intent': 'Deny_Request_Policy', 'speaker': 'Agent', 'time_of_interaction': '2025-11-10 12:55:00', 'turn_index': 12, 'reason_for_call': 'Customer called seeking clarification on a denied life insurance claim and inquired about refund eligibility.'}, score=-1.475812315940857, graph_score=0.0, semantic_score=0.0, final_score=0.0, intent='Deny_Request_Policy'),
#  RetrievalResult(transcript_id='73077d8b-0ffe-40cf-91d7-9c904c87173b', turn_index=14, content=["Customer: what kind of conditions i mean i just want to know if it's possible or not", "Agent: well generally if you purchased a basic economy fare and um request a refund after a certain period it's usually denied", "Customer: so you're saying i can't get my money back after all i mean that's frustrating", "Agent: i'm really sorry noah based on what i see here your refund request has been um denied actually because it does not meet our criteria", "Customer: denied seriously that's not right uh what am i supposed to do with a voucher now", "Agent: i realize this is disappointing you could um consider options like travel credits or meal vouchers in some cases but for your situation it's not applicable", "Customer: wait so you're saying there's no cash refund and i can't even get credits what's the point"], metadata={'speaker': 'Agent', 'secondary_intent': 'Deny_Request_Policy', 'turn_index': 14, 'domain': 'Insurance', 'transcript_id': '73077d8b-0ffe-40cf-91d7-9c904c87173b', 'turn_id': '73077d8b-0ffe-40cf-91d7-9c904c87173b_14', 'type': 'turn_with_context', 'time_of_interaction': '2025-11-07 12:52:00', 'global_intent': 'Refund Policy', 'reason_for_call': 'The customer, Noah Bell, called to inquire about receiving a cash refund instead of a voucher for a canceled Coastal Wings flight.', 'primary_intent': 'Billing & Refunds'}, score=-1.5564817190170288, graph_score=0.0, semantic_score=0.0, final_score=0.0, intent='Deny_Request_Policy')]

# %%
query = "Reason for refund rejection"
results = retriever.retrieve_dual(query)

# %%
results
# Out:
# []

# %% [markdown]
# ## 4. Test Agent Retrieval Node
# Tests the agent's retrieval node logic.

# %%
from observe_ai.src.rag.agentic_graph import ObserveAIAgent
from langchain_core.messages import HumanMessage
from src.rag.retriever import Retriever
from src.rag.embeddings import EmbeddingModel
from src.rag.vector_store import VectorStore
from src.rag.graph_store import GraphStore
from src.rag.transcript_store import TranscriptStore
from sentence_transformers import CrossEncoder
from src.rag.causal_pipeline import CausalPipeline

reranker = CrossEncoder(Config.RERANKER_MODEL)
embedding_model = EmbeddingModel()
vector_store = VectorStore()
graph_store = GraphStore()
transcript_store = TranscriptStore()
causal = CausalPipeline()
# Use the custom Retriever class
retriever = Retriever(
    embedding_model=embedding_model,
    vector_store=vector_store,
    graph_store=graph_store,
    transcript_store=transcript_store,
    reranker=reranker
)
print("Retriever initialized.")
agent = ObserveAIAgent(retriever=retriever, causal_pipeline=causal)
print("Agent initialized.")

# Create a dummy state
state = {
    "messages": [HumanMessage(content="What causes delays and claim approval?")],
    "context": None,
    "retrieved_results": None
}

# Run the retrieve node directly
new_state = agent.retrieve_node(state)

print("\nRetrieve Node Output:")
print(f"Context Length: {len(new_state['context'])}")
print(f"Number of Results: {len(new_state['retrieved_results'])}")
print("\nGenerated Context Preview:")
print(new_state['context'][:500])
# Out:
# 2025-12-03 04:02:16,481 - src.agent.agentic_graph - INFO - Initialized ObserveAIAgent
# 2025-12-03 04:02:16,483 - src.agent.agentic_graph - INFO - Retrieve node: Fetching documents...
# Agent initialized.
# 2025-12-03 04:02:19,734 - src.rag.retriever - INFO - Classified query 'Why was the refund rejected?' as intent: Question_Approval
# 2025-12-03 04:02:20,341 - src.rag.retriever - INFO - Related intents for Question_Approval: {'Clarify_Eligibility': 1.0, 'Offer_Partial_Increase': 0.34328358208955223, 'Apologize_for_Delays': 0.3164179104477612, 'Acknowledge_or_Confirm': 0.28059701492537314, 'Ask_for_Clarification': 0.24776119402985075, 'Question_Approval': 1.0}
# Sorting results by score:
# Expanding context for top results:
#
# Retrieve Node Output:
# Context Length: 4152
# Number of Results: 5
#
# Generated Context Preview:
# --- Result 1 (Score: 0.65, Intent: Question_Approval) ---
# Transcript ID: cae47e9a-e073-4a8f-b80a-af32f9bcc187, Turn Index: 15
# Agent: right let me check um the merchant evidence uh does support the denial of your refund
# Customer: denial what are you serious i thought this uh was straightforward
# Agent: i know this is frustrating and i'm really sorry for um any inconvenience the evidence we received wasn't enough um to move forward with the refund
# Customer: so it's actually denied that's ridiculous

# %%
print(new_state['context'])
# Out:
# --- Result 1 (Score: 0.65, Intent: Question_Approval) ---
# Transcript ID: cae47e9a-e073-4a8f-b80a-af32f9bcc187, Turn Index: 15
# Agent: right let me check um the merchant evidence uh does support the denial of your refund
# Customer: denial what are you serious i thought this uh was straightforward
# Agent: i know this is frustrating and i'm really sorry for um any inconvenience the evidence we received wasn't enough um to move forward with the refund
# Customer: so it's actually denied that's ridiculous
# Agent: yes unfortunately the final outcome unfortunately is denied i realize that's not what you wanted to hear
# Customer: well why didn't anyone tell me this sooner it just feels like you're wasting my time
# Agent: i completely understand your frustration ava and um i'm very sorry for the delay in communication
#
#
# --- Result 2 (Score: 0.64, Intent: Question_Approval) ---
# Transcript ID: 65be5609-4157-47c6-b469-3cc04f816b08, Turn Index: 5
# Agent: right about your life insurance policy
# Customer: yeah exactly i mean um it's pol 1234 567 i need to dispute the denial of my um refund klame
# Agent: thank you for that let me review your claim details real quick just one moment i'll check it out
# Customer: sure take your time i just uh i don't understand why it got denied
# Agent: okay so i see here that the claim was submitted but actually um the terms of your policy uh didn't quite support the refund request you know
# Customer: but the infomation i provided clearly shows i met the requirements
# Agent: i do understand victoria it looks like um the specific clause about coverage limits might be affecting this
#
#
# --- Result 3 (Score: 0.57, Intent: Ask_for_Clarification) ---
# Transcript ID: 93d77a87-487a-4daf-9f91-38e3e8e0c3fb, Turn Index: 9
# Agent: i see so regarding our refund policy um typically uh we do not issue cash refunds for um certain fare classes like economy unless specific conditions are met
# Customer: but i thought i could get something back um maybe a voucher or even cash if i meet those conditions
# Agent: well in your case uh the refund was denied based on our policy which actually i can explain
# Customer: sure could you clarify that
# Agent: yes so uh primarily refunds depend on the terms of the specific fare you booked right
# Customer: i see and my ticket was um economy right
# Agent: exactly and for economy unfortunately we don't offer cash or vouchers in this scenario
#
#
# --- Result 4 (Score: 0.57, Intent: Ask_for_Clarification) ---
# Transcript ID: 33c8c520-8537-42d1-93b6-1c5100ba6a8c, Turn Index: 7
# Agent: thank you let me pull that up okay i see your claim here so um what specifically uh would you like to know about the refund status
# Customer: well i'm wondering um why i didn't receive a refund after my claim review
# Agent: i can help with that there was a review process and i can explain why a refund wasn't granted actually there were some you know criteria that were not met
# Customer: um right i'd like to uh understand that better
# Agent: absolutely your coverage limit is actually set at a medium band and with your deductible also being medium it affects refund eligibility um that is you see
# Customer: so wait are you um saying i won't get anything back
# Agent: yes uh unfortunately there are no refunds um granted in your case
#
#
# --- Result 5 (Score: 0.57, Intent: Request_Policy_Clarification) ---
# Transcript ID: bb14f41d-a40e-4277-8960-8e2c0b270ee5, Turn Index: 7
# Agent: thank you okay i uh see your recent transactions just a moment while i pull up the details about your refund
# Customer: yeah and i was told i'd get it um way sooner than this
# Agent: right i see that the refund was for a transaction with reference txn 58479301 but i'm ugh i'm sorry to inform you that it was uh denied due to insufficient evidence from the merchant
# Customer: denied that's ugh that's not what i was expecting
# Agent: i can understand your disappointment nora harborwest's policy requires specific documentation um from the merchant
# Customer: well i was um really hoping that this would be you know an easier process
# Agent: absolutely i can see why you'd expect that would you like um me to guide you through ugh the appeals process

# %% [markdown]
# # Check vector store

# %%
from src.rag.vector_store import VectorStore

# Initialize the store to check contents
print("Checking Vector Store...")
vs = VectorStore()
# vs = vector_store
# 1. Check the count
count = vs.collection.count()
print(f"Total documents in collection: {count}")

# 2. Peek at the data to verify structure
if count > 0:
    print("\n--- Peeking at first item ---")
    # peek() returns a dict with 'ids', 'embeddings', 'metadatas', 'documents'
    peek_data = vs.collection.peek(limit=1)
    
    print(f"ID: {peek_data['ids'][0]}")
    print(f"Metadata: {peek_data['metadatas'][0]}")
    print(f"Document (first 100 chars): {peek_data['documents'][0][:100]}...")
    
    # 3. Test a direct search
    print("\n--- Testing Direct Search ---")
    test_query = "refund"
    results = vs.vector_store.similarity_search_with_score(test_query, k=2)
    
    if results:
        print(f"Found {len(results)} results for '{test_query}':")
        for doc, score in results:
            print(f"  Score: {score:.4f} | Content: {doc.page_content[:50]}...")
    else:
        print(f"No results found for '{test_query}' despite having documents.")
else:
    print("!!! Collection is EMPTY. The vector database needs to be repopulated. !!!")
# Out:
# 2025-12-04 22:25:11,697 - src.rag.embeddings - INFO - Loading embedding model: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-04 22:25:11,698 - src.rag.embeddings - INFO - Using device: cpu
# 2025-12-04 22:25:11,698 - sentence_transformers.SentenceTransformer - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# Checking Vector Store...
# 2025-12-04 22:25:15,916 - src.rag.embeddings - INFO - Initialized embedding model: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-04 22:25:15,916 - src.rag.vector_store - INFO - Initializing Chroma vector store at: d:\DEV\Python\interiit25\Observe\observe_ai\data\vector_db
# 2025-12-04 22:25:15,968 - chromadb.telemetry.product.posthog - INFO - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2025-12-04 22:26:01,899 - src.rag.vector_store - INFO - Vector store initialized. Collection 'rag_collection'
# Loaded with 681979 items.
# Total documents in collection: 681979
#
# --- Peeking at first item ---
# ID: 79327ea0-d8b4-439e-9d6c-10e996678542
# Metadata: {'transcript_id': 'ce44aa4b-13b7-4778-b413-15f37ee15f7a', 'secondary_intent': 'Offer_Resolution', 'time_of_interaction': '2025-11-10 16:23:00', 'primary_intent': 'Hotel_Complaint', 'global_intent': 'Discounts & Promotions', 'domain': 'Insurance', 'type': 'turn_with_context', 'turn_id': 'ce44aa4b-13b7-4778-b413-15f37ee15f7a_0', 'turn_index': 0, 'speaker': 'Agent', 'reason_for_call': 'Inquiry about promotional codes and potential loyalty benefits for booking at Beachfront Suites in Las Vegas.'}
# Document (first 100 chars): Agent: thank you for calling beachfront suites this is isabella nguyen how can i help you today
# Cust...
#
# --- Testing Direct Search ---
# Found 2 results for 'refund':
#   Score: 0.6278 | Content: Customer: no that's it i suppose just um make sure...
#   Score: 0.6379 | Content: Customer: great but i really need to see some acti...

# %% [markdown]
# ## 5. Test New Agentic Graph
# Tests the full self-correcting agent pipeline (Retrieve -> Generate -> Critique -> Loop).

# %%
from src.rag.retriever import Retriever
from src.rag.embeddings import EmbeddingModel
from src.rag.vector_store import VectorStore
from src.rag.graph_store import GraphStore
from src.rag.transcript_store import TranscriptStore
from sentence_transformers import CrossEncoder
from src.rag.causal_pipeline import CausalPipeline
from src.rag.agentic_graph import ObserveAIAgent
from src.config import Config

reranker = CrossEncoder(Config.RERANKER_MODEL)
embedding_model = EmbeddingModel()
vector_store = VectorStore()
graph_store = GraphStore()
transcript_store = TranscriptStore()
causal = CausalPipeline()

retriever = Retriever(
    embedding_model=embedding_model,
    vector_store=vector_store,
    graph_store=graph_store,
    transcript_store=transcript_store,
    reranker=reranker
)
print("Retriever initialized.")
agent = ObserveAIAgent(retriever=retriever, causal_pipeline=causal)
print("Agent initialized.")

# Test Query
query = "What causes delays and claim approval?"
print(f"Running agent with query: '{query}'")

# Run the full agent pipeline
# Note: This might take a few seconds as it involves multiple LLM calls
result = agent.invoke(query)

print("\n--- Agent Output ---")
print(f"Iterations: {result['iterations']}")
print(f"Final Score: {result['final_score']}")
print(f"Number of Retrieved Docs: {len(result['retrieved_results'])}")
print("\nGenerated Response:")
print(result['response'])
# Out:
# 2025-12-04 22:26:40,412 - sentence_transformers.cross_encoder.CrossEncoder - INFO - Use pytorch device: cpu
# 2025-12-04 22:26:40,946 - src.rag.embeddings - INFO - Loading embedding model: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-04 22:26:40,946 - src.rag.embeddings - INFO - Using device: cpu
# 2025-12-04 22:26:40,946 - sentence_transformers.SentenceTransformer - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-04 22:26:44,580 - src.rag.embeddings - INFO - Initialized embedding model: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-04 22:26:44,580 - src.rag.embeddings - INFO - Loading embedding model: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-04 22:26:44,580 - src.rag.embeddings - INFO - Using device: cpu
# 2025-12-04 22:26:44,597 - sentence_transformers.SentenceTransformer - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-04 22:26:48,532 - src.rag.embeddings - INFO - Initialized embedding model: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-04 22:26:48,532 - src.rag.vector_store - INFO - Initializing Chroma vector store at: d:\DEV\Python\interiit25\Observe\observe_ai\data\vector_db
# 2025-12-04 22:26:48,755 - src.rag.vector_store - INFO - Vector store initialized. Collection 'rag_collection'
# Loaded with 681979 items.
# 2025-12-04 22:26:51,233 - src.rag.graph_store - INFO - Connected to Neo4j GraphStore.
# 2025-12-04 22:26:51,233 - src.rag.transcript_store - INFO - Loading transcripts from d:\DEV\Python\interiit25\Observe\observe_ai\data\labelled_transcript_allMiniLM_2.json...
# 2025-12-04 22:26:54,783 - src.rag.transcript_store - INFO - Loaded 19615 transcripts into memory.
# 2025-12-04 22:26:55,173 - src.rag.causal_pipeline - INFO - CausalPipeline: Loading resources...
# Loading schema...
# Loading dataset...
# Loading SCM bundle...
# D:\Users\Abhirup\AppData\Local\Programs\Python\Python311\Lib\pickle.py:1718: UserWarning: [22:26:57] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\data\../common/error_msg.h:83: If you are loading a serialized model (like pickle in Python, RDS in R) or
# configuration generated by an older version of XGBoost, please export the model by calling
# `Booster.save_model` from that version first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/stable/tutorials/saving_model.html
#
# for more details about differences between saving model and serializing.
#
#   setstate(state)
# 2025-12-04 22:26:58,225 - src.rag.agentic_graph - INFO - ---RETRIEVE (Attempt 0)---
# CausalPipeline initialized.
# Retriever initialized.
# Agent initialized.
# Running agent with query: 'What causes delays and claim approval?'
# 2025-12-04 22:27:13,275 - src.rag.retriever - INFO - Reranking 50 candidates...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# 2025-12-04 22:27:16,361 - src.rag.agentic_graph - INFO - Retrieved 10 documents.
# 2025-12-04 22:27:16,365 - src.rag.agentic_graph - INFO - ---GENERATE CAUSAL ANALYSIS---
# 2025-12-04 22:27:24,746 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 5da592e4-38fd-4125-8db2-1520dbf0df57. Skipping SCM.
# 2025-12-04 22:27:24,746 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 786e2d74-949c-4cc5-a027-7f54fff4bf6c. Skipping SCM.
# 2025-12-04 22:27:24,746 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 5da592e4-38fd-4125-8db2-1520dbf0df57. Skipping SCM.
# 2025-12-04 22:27:24,761 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id c3f5ad51-fe26-4ae0-953e-23ec5de526f6. Skipping SCM.
# 2025-12-04 22:27:24,765 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 786e2d74-949c-4cc5-a027-7f54fff4bf6c. Skipping SCM.
# 2025-12-04 22:27:24,770 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 5da592e4-38fd-4125-8db2-1520dbf0df57. Skipping SCM.
# 2025-12-04 22:27:24,772 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 43238112-ea30-49d1-af70-3589f74d53c5. Skipping SCM.
# 2025-12-04 22:27:24,772 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 5248a649-1793-425d-bd9c-9b5ed3bc5955. Skipping SCM.
# 2025-12-04 22:27:24,782 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 5248a649-1793-425d-bd9c-9b5ed3bc5955. Skipping SCM.
# 2025-12-04 22:27:24,782 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 17105fb2-7a42-4cab-bc49-ab784af08ec0. Skipping SCM.
# 2025-12-04 22:27:40,269 - src.rag.agentic_graph - INFO - ---CRITIQUE ANSWER---
# 2025-12-04 22:27:46,456 - src.rag.agentic_graph - INFO - Critique Score: 0.9 | Reason: The analysis demonstrates excellent synthesis, identifying multiple distinct causal patterns across a significant number of cases. Each pattern is well-described, supported by specific case citations, and clearly explains the root cause mechanism and its effect. The counterfactual recommendation is also well-reasoned and directly addresses the identified causal factors.
# --- Agent Output ---
# Iterations: 1
# Final Score: 0.9
# Number of Retrieved Docs: 10
#
# Generated Response:
# **1. Executive Summary**
#
# Delays in claim processing and approval are primarily caused by a combination of factors related to documentation, operational load, and the inherent complexity of the verification process. Customers frequently express frustration due to claims being "pending" without clear reasons, often stemming from the need for comprehensive verification of details, missing or erroneous information in submissions, and high volumes of claims. The lack of transparent communication regarding these common causes further exacerbates customer dissatisfaction.
#
# **2. Key Causal Patterns**
#
# *   **Pattern A: Incomplete, Erroneous, or Unverified Documentation**
#     *   *Description:* A predominant cause of delays is the requirement for thorough verification of submitted details and documentation. This often includes instances where initial submissions are missing crucial documents or contain incorrect information, necessitating further investigation or requests for clarification. Even when customers believe they have submitted "everything needed," the internal verification process can still flag issues or require additional checks.
#     *   *Evidence:*
#         *   In **Case 1, Case 3, and Case 6**, the agent explicitly states, "sometimes the claims process can take a bit longer due to um verification of details."
#         *   **Case 2 and Case 5** highlight "missing documents or err information on the claim" as a cause for delays.
#         *   **Case 4** confirms, "the delay was primarily due to comprehensive verification uh requirements we needed to ensure all documentation you know was correct before approval."
#         *   **Case 7** notes that "paperwork can delay things" and emphasizes "timely submission of all required documents is crucial."
#         *   **Case 8 and Case 9** mention "missing documents or if they're you know waiting for assessments or further information."
#         *   **Case 10** reinforces this, stating, "the actual time for claiming um that may take longer because of all the documentation you think."
#     *   *Effect:* This pattern directly leads to claims remaining in a "pending" status, extended processing times, and significant customer frustration due to perceived lack of progress despite their initial submission efforts.
#
# *   **Pattern B: High Operational Volumes**
#     *   *Description:* Beyond individual claim specifics, the overall volume of claims being processed concurrently can contribute to delays, creating a backlog that extends wait times for all customers.
#     *   *Evidence:*
#         *   In **Case 1, Case 3, and Case 6**, the agent identifies "high volumes of claims right now" as a factor causing delay.
#     *   *Effect:* This operational constraint contributes to the general slowness of the claims process, leading to customer impatience and a desire for "quicker update[s]."
#
# *   **Pattern C: Need for Further Assessments and Information Gathering**
#     *   *Description:* Claims can be delayed while awaiting internal assessments or additional information that may not be directly related to initial documentation errors but rather to the nature of the claim itself (e.g., damage assessments, policy reviews).
#     *   *Evidence:*
#         *   **Case 8 and Case 9** mention "waiting for assessments or further information" as a cause for delay.
#         *   **Case 2 and Case 5** also touch upon the need to "review your uh coverage limits," which can be part of the assessment process impacting approval.
#     *   *Effect:* This extends the resolution timeline, keeping claims in a pending state and contributing to customer uncertainty about the approval process.
#
# **3. Counterfactual Recommendation**
#
# *   *Observation:* We observed that when customers are left in the dark about the specific reasons for delays, or when the process requires extensive back-and-forth for documentation and verification, outcomes are negative, leading to frustration and repeated inquiries about claim status.
# *   *Hypothesis:* If agents were empowered and trained to proactively communicate the *specific* reasons for delays (e.g., "We are awaiting X document from you," or "Your claim is currently in the comprehensive verification queue due to high volume, expected resolution in Y days"), and if a clear, accessible checklist of required documents was provided upfront, we expect a significant reduction in customer frustration and follow-up calls, potentially streamlining the claims process by reducing the need for repeated information gathering.
#
# **4. Citations**
#
# *   Case 1: 5da592e4-38fd-4125-8db2-1520dbf0df57
# *   Case 2: 786e2d74-949c-4cc5-a027-7f54fff4bf6c
# *   Case 3: 5da592e4-38fd-4125-8db2-1520dbf0df57
# *   Case 4: c3f5ad51-fe26-4ae0-953e-23ec5de526f6
# *   Case 5: 786e2d74-949c-4cc5-a027-7f54fff4bf6c
# *   Case 6: 5da592e4-38fd-4125-8db2-1520dbf0df57
# *   Case 7: 43238112-ea30-49d1-af70-3589f74d53c5
# *   Case 8: 5248a649-1793-425d-bd9c-9b5ed3bc5955
# *   Case 9: 5248a649-1793-425d-bd9c-9b5ed3bc5955
# *   Case 10: 17105fb2-7a42-4cab-bc49-ab784af08ec0

# %% [markdown]
# ## 6. Test Causal Pipeline
# Tests the causal inference pipeline with query interpretation and SCM simulation.

# %%
from src.rag.causal_pipeline import CausalPipeline

# %%
import importlib,src.rag.causal_pipeline
importlib.reload(src.rag.causal_pipeline)

from src.rag.causal_pipeline import CausalPipeline

# %%
# Initialize Causal Pipeline
print("Initializing Causal Pipeline...")
causal_pipeline = CausalPipeline()
print("Causal Pipeline initialized successfully.\n")

# Test transcript IDs
test_transcript_ids = [
    "ce44aa4b-13b7-4778-b413-15f37ee15f7a",
    "6447a610-7803-4e29-918f-7255ece57195",
    "1e47a0f1-6334-45b3-8d04-84f8795d8d60"
]

# Test query - counterfactual question
test_query = "How would customer satisfaction have changed if the agent had shown more empathy during the interaction?"

print(f"Test Query: {test_query}")
print(f"Test Transcript IDs: {test_transcript_ids}\n")
print("Running causal analysis...\n")

# Run the pipeline
result = causal_pipeline.run(test_query, test_transcript_ids)

print("="*80)
print(result)
print("="*80)
# Out:
# 2025-12-04 20:19:38,407 - src.rag.causal_pipeline - INFO - CausalPipeline: Loading resources...
# Initializing Causal Pipeline...
# Loading schema...
# Loading dataset...
# Loading SCM bundle...
# Loading SCM bundle...
# CausalPipeline initialized.
# Causal Pipeline initialized successfully.
#
# Test Query: How would customer satisfaction have changed if the agent had shown more empathy during the interaction?
# Test Transcript IDs: ['ce44aa4b-13b7-4778-b413-15f37ee15f7a', '6447a610-7803-4e29-918f-7255ece57195', '1e47a0f1-6334-45b3-8d04-84f8795d8d60']
#
# Running causal analysis...
#
# CausalPipeline initialized.
# Causal Pipeline initialized successfully.
#
# Test Query: How would customer satisfaction have changed if the agent had shown more empathy during the interaction?
# Test Transcript IDs: ['ce44aa4b-13b7-4778-b413-15f37ee15f7a', '6447a610-7803-4e29-918f-7255ece57195', '1e47a0f1-6334-45b3-8d04-84f8795d8d60']
#
# Running causal analysis...
#
# ================================================================================
# Causal Analysis Results:
#
# Transcript ID: ce44aa4b-13b7-4778-b413-15f37ee15f7a
# Query Type: counterfactual
# Interventions:
#   - emo_sadness_mean: 0.0010
#   - emo_anger_mean: 0.0009
#   - emo_approval_mean: 0.3630
#   - emo_gratitude_mean: 0.2243
# Targets (Before -> After, Delta):
#   - sentiment_end: 5.0000 -> 4.9622 (Delta: -0.0378)
#   - sentiment_change: 2.0000 -> 2.0000 (Delta: 0.0000)
#
# Transcript ID: 6447a610-7803-4e29-918f-7255ece57195
# Query Type: counterfactual
# Interventions:
#   - emo_sadness_mean: 0.0010
#   - emo_anger_mean: 0.0009
#   - emo_approval_mean: 0.2273
#   - emo_gratitude_mean: 0.2728
# Targets (Before -> After, Delta):
#   - sentiment_end: 3.0000 -> 3.0379 (Delta: 0.0379)
#   - sentiment_change: 2.0000 -> 2.0000 (Delta: 0.0000)
#
# Transcript ID: 1e47a0f1-6334-45b3-8d04-84f8795d8d60
# Query Type: counterfactual
# Interventions:
#   - emo_sadness_mean: 0.0010
#   - emo_anger_mean: 0.0009
#   - emo_approval_mean: 0.2872
#   - emo_gratitude_mean: 0.3002
# Targets (Before -> After, Delta):
#   - sentiment_end: 5.0000 -> 4.9843 (Delta: -0.0157)
#   - sentiment_change: 4.0000 -> 4.0000 (Delta: 0.0000)
# ================================================================================
# ================================================================================
# Causal Analysis Results:
#
# Transcript ID: ce44aa4b-13b7-4778-b413-15f37ee15f7a
# Query Type: counterfactual
# Interventions:
#   - emo_sadness_mean: 0.0010
#   - emo_anger_mean: 0.0009
#   - emo_approval_mean: 0.3630
#   - emo_gratitude_mean: 0.2243
# Targets (Before -> After, Delta):
#   - sentiment_end: 5.0000 -> 4.9622 (Delta: -0.0378)
#   - sentiment_change: 2.0000 -> 2.0000 (Delta: 0.0000)
#
# Transcript ID: 6447a610-7803-4e29-918f-7255ece57195
# Query Type: counterfactual
# Interventions:
#   - emo_sadness_mean: 0.0010
#   - emo_anger_mean: 0.0009
#   - emo_approval_mean: 0.2273
#   - emo_gratitude_mean: 0.2728
# Targets (Before -> After, Delta):
#   - sentiment_end: 3.0000 -> 3.0379 (Delta: 0.0379)
#   - sentiment_change: 2.0000 -> 2.0000 (Delta: 0.0000)
#
# Transcript ID: 1e47a0f1-6334-45b3-8d04-84f8795d8d60
# Query Type: counterfactual
# Interventions:
#   - emo_sadness_mean: 0.0010
#   - emo_anger_mean: 0.0009
#   - emo_approval_mean: 0.2872
#   - emo_gratitude_mean: 0.3002
# Targets (Before -> After, Delta):
#   - sentiment_end: 5.0000 -> 4.9843 (Delta: -0.0157)
#   - sentiment_change: 4.0000 -> 4.0000 (Delta: 0.0000)
# ================================================================================

# %%
# Test with a different query - interventional question
test_query_2 = "What happens to resolution time if we increase agent response speed?"

print(f"\nTest Query 2: {test_query_2}\n")
print("Running causal analysis...\n")

result_2 = causal_pipeline.run(test_query_2, test_transcript_ids)

print("="*80)
print(result_2)
print("="*80)
# Out:
# Test Query 2: What happens to resolution time if we increase agent response speed?
#
# Running causal analysis...
#
# ================================================================================
# Causal Analysis Results:
#
# Transcript ID: ce44aa4b-13b7-4778-b413-15f37ee15f7a
# Query Type: interventional
# Interventions:
#   - avg_agent_utt_len: 8.3812
# No targets specified.
#
# Transcript ID: 6447a610-7803-4e29-918f-7255ece57195
# Query Type: interventional
# Interventions:
#   - avg_agent_utt_len: 7.6193
# No targets specified.
#
# Transcript ID: 1e47a0f1-6334-45b3-8d04-84f8795d8d60
# Query Type: interventional
# Interventions:
#   - avg_agent_utt_len: 11.8193
# No targets specified.
# ================================================================================
# ================================================================================
# Causal Analysis Results:
#
# Transcript ID: ce44aa4b-13b7-4778-b413-15f37ee15f7a
# Query Type: interventional
# Interventions:
#   - avg_agent_utt_len: 8.3812
# No targets specified.
#
# Transcript ID: 6447a610-7803-4e29-918f-7255ece57195
# Query Type: interventional
# Interventions:
#   - avg_agent_utt_len: 7.6193
# No targets specified.
#
# Transcript ID: 1e47a0f1-6334-45b3-8d04-84f8795d8d60
# Query Type: interventional
# Interventions:
#   - avg_agent_utt_len: 11.8193
# No targets specified.
# ================================================================================

# %%
# Test with a descriptive query
test_query_3 = "Describe the agent's communication style in these interactions"

print(f"\nTest Query 3: {test_query_3}\n")
print("Running causal analysis...\n")

result_3 = causal_pipeline.run(test_query_3, test_transcript_ids)

print("="*80)
print(result_3)
print("="*80)
# Out:
# Test Query 3: Describe the agent's communication style in these interactions
#
# Running causal analysis...
# 2025-12-04 20:24:05,126 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id ce44aa4b-13b7-4778-b413-15f37ee15f7a. Skipping SCM.
# 2025-12-04 20:24:05,126 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 6447a610-7803-4e29-918f-7255ece57195. Skipping SCM.
# 2025-12-04 20:24:05,126 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 1e47a0f1-6334-45b3-8d04-84f8795d8d60. Skipping SCM.
# 2025-12-04 20:24:05,126 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 6447a610-7803-4e29-918f-7255ece57195. Skipping SCM.
# 2025-12-04 20:24:05,126 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 1e47a0f1-6334-45b3-8d04-84f8795d8d60. Skipping SCM.
# ================================================================================
# Causal Analysis Results:
#
# Transcript ID: ce44aa4b-13b7-4778-b413-15f37ee15f7a
# Query Type: descriptive
# Targets (Before -> After, Delta):
#   - num_agent_turns: 14.0000 -> 14.0000 (Delta: 0.0000)
#   - total_words_agent: 244.0000 -> 244.0000 (Delta: 0.0000)
#   - avg_agent_utt_len: 17.4286 -> 17.4286 (Delta: 0.0000)
#
# Transcript ID: 6447a610-7803-4e29-918f-7255ece57195
# Query Type: descriptive
# Targets (Before -> After, Delta):
#   - num_agent_turns: 15.0000 -> 15.0000 (Delta: 0.0000)
#   - total_words_agent: 250.0000 -> 250.0000 (Delta: 0.0000)
#   - avg_agent_utt_len: 16.6667 -> 16.6667 (Delta: 0.0000)
#
# Transcript ID: 1e47a0f1-6334-45b3-8d04-84f8795d8d60
# Query Type: descriptive
# Targets (Before -> After, Delta):
#   - num_agent_turns: 15.0000 -> 15.0000 (Delta: 0.0000)
#   - total_words_agent: 313.0000 -> 313.0000 (Delta: 0.0000)
#   - avg_agent_utt_len: 20.8667 -> 20.8667 (Delta: 0.0000)
# ================================================================================

# %% [markdown]
# ## 7. Test Agent Memory & Retry Logic
# Tests the agent's ability to store memory and handle follow-up queries with the new logic.

# %%
from src.rag.agentic_graph import ObserveAIAgent
from src.rag.retriever import Retriever
from src.rag.causal_pipeline import CausalPipeline
from src.rag.embeddings import EmbeddingModel
from src.rag.vector_store import VectorStore
from src.rag.graph_store import GraphStore
from src.rag.transcript_store import TranscriptStore
from sentence_transformers import CrossEncoder
from src.config import Config
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model=Config.GEMINI_MODEL,
    google_api_key=Config.GEMINI_API_KEY,
    temperature=0.1
)
# Re-initialize components to ensure clean state
reranker = CrossEncoder(Config.RERANKER_MODEL)
embedding_model = EmbeddingModel()
vector_store = VectorStore()
graph_store = GraphStore()
transcript_store = TranscriptStore()
causal = CausalPipeline(llm=llm)

retriever = Retriever(
    embedding_model=embedding_model,
    vector_store=vector_store,
    graph_store=graph_store,
    transcript_store=transcript_store,
    reranker=reranker,
    llm=llm
)
# Out:
# 2025-12-05 16:17:48,087 - sentence_transformers.cross_encoder.CrossEncoder - INFO - Use pytorch device: cpu
# 2025-12-05 16:17:48,623 - src.rag.embeddings - INFO - Loading embedding model: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-05 16:17:48,624 - src.rag.embeddings - INFO - Using device: cpu
# 2025-12-05 16:17:48,636 - sentence_transformers.SentenceTransformer - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-05 16:17:52,554 - src.rag.embeddings - INFO - Initialized embedding model: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-05 16:17:52,554 - src.rag.embeddings - INFO - Loading embedding model: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-05 16:17:52,570 - src.rag.embeddings - INFO - Using device: cpu
# 2025-12-05 16:17:52,579 - sentence_transformers.SentenceTransformer - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-05 16:17:57,265 - src.rag.embeddings - INFO - Initialized embedding model: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-05 16:17:57,267 - src.rag.vector_store - INFO - Initializing Chroma vector store at: d:\DEV\Python\interiit25\Observe\observe_ai\data\vector_db
# 2025-12-05 16:21:51,330 - src.rag.vector_store - INFO - Vector store initialized. Collection 'rag_collection'
# Loaded with 681979 items.
# 2025-12-05 16:21:53,386 - src.rag.graph_store - INFO - Connected to Neo4j GraphStore.
# 2025-12-05 16:21:53,388 - src.rag.transcript_store - INFO - Loading transcripts from d:\DEV\Python\interiit25\Observe\observe_ai\data\labelled_transcript_bert.json...
# 2025-12-05 16:21:58,794 - src.rag.transcript_store - INFO - Loaded 19615 transcripts into memory.
# 2025-12-05 16:21:58,811 - src.rag.causal_pipeline - INFO - CausalPipeline: Loading resources...
# Loading schema...
# Loading dataset...
# Loading SCM bundle...
# D:\Users\Abhirup\AppData\Local\Programs\Python\Python311\Lib\pickle.py:1718: UserWarning: [16:22:00] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\data\../common/error_msg.h:83: If you are loading a serialized model (like pickle in Python, RDS in R) or
# configuration generated by an older version of XGBoost, please export the model by calling
# `Booster.save_model` from that version first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/stable/tutorials/saving_model.html
#
# for more details about differences between saving model and serializing.
#
#   setstate(state)
# CausalPipeline initialized.

# %%
# import importlib,src.rag.retriever
# importlib.reload(src.rag.retriever)
# from src.rag.retriever import Retriever
# retriever = Retriever(
#     embedding_model=embedding_model,
#     vector_store=vector_store,
#     graph_store=graph_store,
#     transcript_store=transcript_store,
#     reranker=reranker
# )

# %%
import importlib,src.rag.agentic_graph
importlib.reload(src.rag.agentic_graph)
from src.rag.agentic_graph import ObserveAIAgent

# %%
agent = ObserveAIAgent(retriever=retriever, causal_pipeline=causal, llm=llm, embedder=embedding_model)
print("Agent initialized for Memory Test.")
# Out:
# Agent initialized for Memory Test.

# %%
# 1. First Query (Should trigger 'retrieve' routing and store memory)
query1 = "What are the main reasons for customer dissatisfaction?"
print(f"\n--- Turn 1: {query1} ---")
result1 = agent.invoke(query1)
print(f"Memory Stored: {result1['memory_stored']}")
print(f"Response Length: {len(result1['response'])}")
# Out:
# --- Turn 1: What are the main reasons for customer dissatisfaction? ---
# 2025-12-05 17:23:46,849 - src.rag.agentic_graph - INFO - Rewrites generated: 5
# 2025-12-05 17:23:46,849 - src.rag.agentic_graph - INFO - First conversation detected (no memories). Routing: retrieve
# 2025-12-05 17:23:46,849 - src.rag.agentic_graph - INFO - Running full dual retrieval (retrieve) on 5 queries.
# 2025-12-05 17:23:46,849 - src.rag.agentic_graph - INFO - First conversation detected (no memories). Routing: retrieve
# 2025-12-05 17:23:46,849 - src.rag.agentic_graph - INFO - Running full dual retrieval (retrieve) on 5 queries.
# Rewritten queries:
#
# - What causes customer dissatisfaction?
# - Why do customers become dissatisfied?
# - Provide examples of situations that lead to customer dissatisfaction.
# - How could customer dissatisfaction have been prevented?
# - What specific product or service issues cause customer dissatisfaction?
# Classified Intent: Ask_for_Clarification
# Classified Intent: Ask_for_Clarification
# Classified Intent: Ask_for_Clarification
# Classified Intent: Ask_for_Clarification
# Classified Intent: Ask_for_Clarification
# Classified Intent: Ask_for_Clarification
# Classified Intent: Ask_for_Clarification
# Classified Intent: Ask_for_Clarification
# Classified Intent: Diagnose_Issue
# Classified Intent: Diagnose_Issue
# 2025-12-05 17:24:20,490 - src.rag.retriever - INFO - Batch reranking 250 pairs across 5 queries...
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# 2025-12-05 17:24:30,991 - src.rag.agentic_graph - INFO - Retrieved 37 docs
# 2025-12-05 17:24:30,994 - src.rag.agentic_graph - INFO - ---GENERATE CAUSAL ANALYSIS---
# 2025-12-05 17:24:30,994 - src.rag.agentic_graph - INFO - ---GENERATE CAUSAL ANALYSIS---
# 2025-12-05 17:24:33,534 - src.rag.agentic_graph - INFO - Generation Mode: analysis
# 2025-12-05 17:24:33,534 - src.rag.agentic_graph - INFO - Generation Mode: analysis
# 2025-12-05 17:24:39,681 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 8646d0c8-3c73-406a-85c9-1f190be0342a. Skipping SCM.
# 2025-12-05 17:24:39,690 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id f83cd9ff-0bad-4d3c-a0ec-b66ff586faa0. Skipping SCM.
# 2025-12-05 17:24:39,690 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 323a297d-2b51-4768-8330-71fe5f49a303. Skipping SCM.
# 2025-12-05 17:24:39,700 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 0b335e64-038a-4ce1-9bf9-5c7f6de296d1. Skipping SCM.
# 2025-12-05 17:24:39,681 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 8646d0c8-3c73-406a-85c9-1f190be0342a. Skipping SCM.
# 2025-12-05 17:24:39,690 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id f83cd9ff-0bad-4d3c-a0ec-b66ff586faa0. Skipping SCM.
# 2025-12-05 17:24:39,690 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 323a297d-2b51-4768-8330-71fe5f49a303. Skipping SCM.
# 2025-12-05 17:24:39,700 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 0b335e64-038a-4ce1-9bf9-5c7f6de296d1. Skipping SCM.
# 2025-12-05 17:24:39,708 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 323a297d-2b51-4768-8330-71fe5f49a303. Skipping SCM.
# 2025-12-05 17:24:39,713 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 9f68956e-b8a6-4e37-9486-c94e41b87824. Skipping SCM.
# 2025-12-05 17:24:39,719 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 4f790eae-bd55-4f81-9932-cc95f8163e09. Skipping SCM.
# 2025-12-05 17:24:39,708 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 323a297d-2b51-4768-8330-71fe5f49a303. Skipping SCM.
# 2025-12-05 17:24:39,713 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 9f68956e-b8a6-4e37-9486-c94e41b87824. Skipping SCM.
# 2025-12-05 17:24:39,719 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 4f790eae-bd55-4f81-9932-cc95f8163e09. Skipping SCM.
# 2025-12-05 17:24:39,725 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id ecace59b-026f-4b00-bfe1-2bbb9d8ad1d8. Skipping SCM.
# 2025-12-05 17:24:39,731 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 2381d161-9941-45b6-8a88-1c7782109175. Skipping SCM.
# 2025-12-05 17:24:39,725 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id ecace59b-026f-4b00-bfe1-2bbb9d8ad1d8. Skipping SCM.
# 2025-12-05 17:24:39,731 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 2381d161-9941-45b6-8a88-1c7782109175. Skipping SCM.
# 2025-12-05 17:24:39,738 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 1e39e3dc-3a93-44b4-b561-332e86c4186c. Skipping SCM.
# 2025-12-05 17:24:39,749 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id e98c51a4-e396-498b-b754-48f0ad973819. Skipping SCM.
# 2025-12-05 17:24:39,755 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 20b65c41-db2b-458b-b6b2-489ff889294d. Skipping SCM.
# 2025-12-05 17:24:39,738 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 1e39e3dc-3a93-44b4-b561-332e86c4186c. Skipping SCM.
# 2025-12-05 17:24:39,749 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id e98c51a4-e396-498b-b754-48f0ad973819. Skipping SCM.
# 2025-12-05 17:24:39,755 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 20b65c41-db2b-458b-b6b2-489ff889294d. Skipping SCM.
# 2025-12-05 17:24:39,755 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 05b57661-d858-43b5-a4c7-d6f719acb68c. Skipping SCM.
# 2025-12-05 17:24:39,770 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 1d672a15-2b48-4bb8-a2ee-f57d6e09800d. Skipping SCM.
# 2025-12-05 17:24:39,777 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id e1e8889c-fa72-48e1-9360-822b8c5f3903. Skipping SCM.
# 2025-12-05 17:24:39,755 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 05b57661-d858-43b5-a4c7-d6f719acb68c. Skipping SCM.
# 2025-12-05 17:24:39,770 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 1d672a15-2b48-4bb8-a2ee-f57d6e09800d. Skipping SCM.
# 2025-12-05 17:24:39,777 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id e1e8889c-fa72-48e1-9360-822b8c5f3903. Skipping SCM.
# 2025-12-05 17:24:39,785 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id d33a0eac-98df-4849-bd8a-ff898b37c717. Skipping SCM.
# 2025-12-05 17:24:39,792 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 298de186-e74b-4f0c-b59b-23c1beaa629e. Skipping SCM.
# 2025-12-05 17:24:39,785 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id d33a0eac-98df-4849-bd8a-ff898b37c717. Skipping SCM.
# 2025-12-05 17:24:39,792 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 298de186-e74b-4f0c-b59b-23c1beaa629e. Skipping SCM.
# 2025-12-05 17:24:39,798 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 3efcb3bc-da76-4ccd-abd0-c8d2dc15509a. Skipping SCM.
# 2025-12-05 17:24:39,806 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id a7a56525-082b-4885-a611-54972ca31bce. Skipping SCM.
# 2025-12-05 17:24:39,807 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 31a38350-0f9b-44d0-8652-9fbe94e901c0. Skipping SCM.
# 2025-12-05 17:24:39,798 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 3efcb3bc-da76-4ccd-abd0-c8d2dc15509a. Skipping SCM.
# 2025-12-05 17:24:39,806 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id a7a56525-082b-4885-a611-54972ca31bce. Skipping SCM.
# 2025-12-05 17:24:39,807 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 31a38350-0f9b-44d0-8652-9fbe94e901c0. Skipping SCM.
# 2025-12-05 17:24:39,823 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id b871d091-388c-4292-b963-ccf1e6beb3ad. Skipping SCM.
# 2025-12-05 17:24:39,829 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id d580d734-4d76-4988-af4d-6d70aeb1f829. Skipping SCM.
# 2025-12-05 17:24:39,836 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id d998269a-f5da-41c1-a7c9-7d9173001212. Skipping SCM.
# 2025-12-05 17:24:39,823 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id b871d091-388c-4292-b963-ccf1e6beb3ad. Skipping SCM.
# 2025-12-05 17:24:39,829 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id d580d734-4d76-4988-af4d-6d70aeb1f829. Skipping SCM.
# 2025-12-05 17:24:39,836 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id d998269a-f5da-41c1-a7c9-7d9173001212. Skipping SCM.
# 2025-12-05 17:24:39,841 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 1e323200-9c5f-4fb4-a30f-d1e6478f7df9. Skipping SCM.
# 2025-12-05 17:24:39,841 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 1e323200-9c5f-4fb4-a30f-d1e6478f7df9. Skipping SCM.
# 2025-12-05 17:24:39,850 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 7a7dd000-853a-4525-81c9-2af6a3320e34. Skipping SCM.
# 2025-12-05 17:24:39,857 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 58d01e7a-3b9b-4a41-9ee5-de60db062588. Skipping SCM.
# 2025-12-05 17:24:39,850 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 7a7dd000-853a-4525-81c9-2af6a3320e34. Skipping SCM.
# 2025-12-05 17:24:39,857 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 58d01e7a-3b9b-4a41-9ee5-de60db062588. Skipping SCM.
# 2025-12-05 17:24:39,867 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 3010f32e-ae02-4801-8de5-0e6f975186c4. Skipping SCM.
# 2025-12-05 17:24:39,876 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 6218ed5f-bdb7-4b3b-8380-1c7d3f93b5fa. Skipping SCM.
# 2025-12-05 17:24:39,886 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 6218ed5f-bdb7-4b3b-8380-1c7d3f93b5fa. Skipping SCM.
# 2025-12-05 17:24:39,867 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 3010f32e-ae02-4801-8de5-0e6f975186c4. Skipping SCM.
# 2025-12-05 17:24:39,876 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 6218ed5f-bdb7-4b3b-8380-1c7d3f93b5fa. Skipping SCM.
# 2025-12-05 17:24:39,886 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 6218ed5f-bdb7-4b3b-8380-1c7d3f93b5fa. Skipping SCM.
# 2025-12-05 17:24:39,892 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 1f289ffe-74f9-4ff0-b7b5-baddc1b86d36. Skipping SCM.
# 2025-12-05 17:24:39,903 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 963c9168-5351-4f90-9c44-449bd73d4440. Skipping SCM.
# 2025-12-05 17:24:39,892 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 1f289ffe-74f9-4ff0-b7b5-baddc1b86d36. Skipping SCM.
# 2025-12-05 17:24:39,903 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 963c9168-5351-4f90-9c44-449bd73d4440. Skipping SCM.
# 2025-12-05 17:24:39,910 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id d7ebc2ce-024a-4dfa-982c-efb903c35905. Skipping SCM.
# 2025-12-05 17:24:39,919 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 949833e3-ad0c-4450-afe1-b0d05dbe89f4. Skipping SCM.
# 2025-12-05 17:24:39,924 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id b5947e8a-5b0f-4338-b02c-d7803bf72ea2. Skipping SCM.
# 2025-12-05 17:24:39,910 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id d7ebc2ce-024a-4dfa-982c-efb903c35905. Skipping SCM.
# 2025-12-05 17:24:39,919 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 949833e3-ad0c-4450-afe1-b0d05dbe89f4. Skipping SCM.
# 2025-12-05 17:24:39,924 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id b5947e8a-5b0f-4338-b02c-d7803bf72ea2. Skipping SCM.
# 2025-12-05 17:24:39,935 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id fcf6bf5c-9088-44c8-ba8d-c6f450ad7746. Skipping SCM.
# 2025-12-05 17:24:39,941 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id fead89a0-a8b4-49aa-b6ed-cf7672d643b6. Skipping SCM.
# 2025-12-05 17:24:39,950 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 20b65c41-db2b-458b-b6b2-489ff889294d. Skipping SCM.
# 2025-12-05 17:24:39,935 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id fcf6bf5c-9088-44c8-ba8d-c6f450ad7746. Skipping SCM.
# 2025-12-05 17:24:39,941 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id fead89a0-a8b4-49aa-b6ed-cf7672d643b6. Skipping SCM.
# 2025-12-05 17:24:39,950 - src.rag.causal_pipeline - INFO - No valid interventions for transcript_id 20b65c41-db2b-458b-b6b2-489ff889294d. Skipping SCM.
# 2025-12-05 17:25:28,718 - src.rag.agentic_graph - INFO - Generation complete.
# 2025-12-05 17:25:28,720 - src.rag.agentic_graph - INFO - ---SUMMARY GENERATION & MEM STORE---
# 2025-12-05 17:25:28,718 - src.rag.agentic_graph - INFO - Generation complete.
# 2025-12-05 17:25:28,720 - src.rag.agentic_graph - INFO - ---SUMMARY GENERATION & MEM STORE---
# 2025-12-05 17:25:32,269 - src.rag.agentic_graph - INFO - Stored MemoryEntry id=0c193d8ae5 with 37 docs.
# 2025-12-05 17:25:32,275 - src.rag.agentic_graph - INFO - ----- REQUEST FLOW SUMMARY -----
# 2025-12-05 17:25:32,275 - src.rag.agentic_graph - INFO - Final generation length: 9341 chars
# 2025-12-05 17:25:32,275 - src.rag.agentic_graph - INFO - Critique pass: False
# 2025-12-05 17:25:32,275 - src.rag.agentic_graph - INFO - Critique reason:
# 2025-12-05 17:25:32,275 - src.rag.agentic_graph - INFO - Memory stored: 1
# 2025-12-05 17:25:32,275 - src.rag.agentic_graph - INFO - Routing: retrieve
# 2025-12-05 17:25:32,275 - src.rag.agentic_graph - INFO - Used rewrites count: 5
# 2025-12-05 17:25:32,269 - src.rag.agentic_graph - INFO - Stored MemoryEntry id=0c193d8ae5 with 37 docs.
# 2025-12-05 17:25:32,275 - src.rag.agentic_graph - INFO - ----- REQUEST FLOW SUMMARY -----
# 2025-12-05 17:25:32,275 - src.rag.agentic_graph - INFO - Final generation length: 9341 chars
# 2025-12-05 17:25:32,275 - src.rag.agentic_graph - INFO - Critique pass: False
# 2025-12-05 17:25:32,275 - src.rag.agentic_graph - INFO - Critique reason:
# 2025-12-05 17:25:32,275 - src.rag.agentic_graph - INFO - Memory stored: 1
# 2025-12-05 17:25:32,275 - src.rag.agentic_graph - INFO - Routing: retrieve
# 2025-12-05 17:25:32,275 - src.rag.agentic_graph - INFO - Used rewrites count: 5
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
# An error occurred: 'ChatGoogleGenerativeAI' object has no attribute 'agenerate_text'. Skipping a sample by assigning it nan score.
# 2025-12-05 17:25:37,768 - ragas.executor - ERROR - Exception raised in Job[2]: ValidationError(1 validation error for ResponseRelevanceOutput
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n    "questio...oncommittal": 0\n}\n```', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid)
# 2025-12-05 17:25:42,609 - ragas.executor - ERROR - Exception raised in Job[0]: ValidationError(1 validation error for Verification
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "reason": ...n  "verdict": 1\n}\n```', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid)
# 2025-12-05 17:25:42,609 - ragas.executor - ERROR - Exception raised in Job[0]: ValidationError(1 validation error for Verification
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "reason": ...n  "verdict": 1\n}\n```', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid)
# 2025-12-05 17:26:03,719 - ragas.executor - ERROR - Exception raised in Job[3]: ValidationError(1 validation error for StatementGeneratorOutput
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "statement...sfaction."\n  ]\n}\n```', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid)
# 2025-12-05 17:26:03,719 - ragas.executor - ERROR - Exception raised in Job[3]: ValidationError(1 validation error for StatementGeneratorOutput
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "statement...sfaction."\n  ]\n}\n```', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid)
# 2025-12-05 17:26:04,570 - src.rag.agentic_graph - INFO - Ragas Scores: {'llm_context_precision_without_reference': nan, 'nv_context_relevance': nan, 'answer_relevancy': nan, 'faithfulness': nan}
# 2025-12-05 17:26:04,570 - src.rag.agentic_graph - INFO - Ragas Scores: {'llm_context_precision_without_reference': nan, 'nv_context_relevance': nan, 'answer_relevancy': nan, 'faithfulness': nan}
# Memory Stored: None
# Response Length: 9341
# Ragas Scores: {'llm_context_precision_without_reference': nan, 'nv_context_relevance': nan, 'answer_relevancy': nan, 'faithfulness': nan}

# %%
print(result1['ragas_scores'])
# Out:
# {'llm_context_precision_without_reference': nan, 'nv_context_relevance': nan, 'answer_relevancy': nan, 'faithfulness': nan}

# %%
print(result1['response'])
# Out:
# **1. Executive Summary**
#
# Customer dissatisfaction primarily stems from a confluence of factors related to perceived poor value, inconsistent service quality, and inadequate communication and support. Customers frequently express frustration when they feel they are paying too much for a service that does not meet their expectations or is inferior to competitors. Recurring issues with service reliability, such as outages, delays, or basic feature limitations, significantly erode trust. Furthermore, a lack of transparency in pricing and policies, coupled with unhelpful or dismissive customer support interactions, exacerbates negative sentiments, often leading customers to consider switching providers.
#
# **2. Key Causal Patterns**
#
# *   **Pattern A: Perceived Poor Value and Unfair Pricing**
#     *   *Description:* Customers consistently express dissatisfaction when they perceive that the price of a product or service is too high relative to its quality or the value offered by competitors. This includes high or unexpected fees, and promotions that are either confusing, poorly communicated, or ultimately fail to deliver the expected discount, sometimes even making pricing appear higher.
#     *   *Evidence:* Customers explicitly state that "the main dissatisfaction stems from the price being too high" (Case 4, 34) and that the "pricing for the budget rooms isn't really appealing" (Case 27). There's a strong sentiment of "get[ting] less value" (Case 6) or that "the value isn't apparent" (Case 9). High last-minute cancellation fees (Case 15) and "pricing discrepancies like unexpected changes in premiums and added fees" (Case 22) are significant pain points. Promotions are noted to "worsen the expectation if not communicated properly" (Case 3, 5) or even "made the pricing appear a lot higher" (Case 6), while denied promotions lead to "seriously disappointing" experiences (Case 14).
#     *   *Effect:* This pattern consistently leads to customers feeling undervalued, frustrated, and actively considering switching to competitors who offer better deals or perceived value. Conversations frequently exhibit elevated levels of annoyance and sadness.
#
# *   **Pattern B: Inconsistent Service Quality and Reliability Issues**
#     *   *Description:* A major driver of customer dissatisfaction is the failure to deliver consistent and reliable service. This encompasses issues such as frequent service outages, unexpected drops in service, chronic speed problems, delays in processing claims or requests, and limitations or poor performance of basic service features.
#     *   *Evidence:* "A significant portion of claims do actually get denied which often leads to customer dissatisfaction" (Case 1), and customers report "delays in processing claims" (Case 31). Inconsistent service (Case 36), "repeated outages" (Case 30), and "chronic speed issues" (Case 32) are frequently cited. Customers complain about "service hasn't been great" (Case 11) and "service drops unexpectedly" (Case 35). Issues with "basic features of economy" (Case 8) and "restrictions" in basic economy fares (Case 17, 20) also contribute to widespread complaints.
#     *   *Effect:* This directly erodes customer trust and loyalty, causing significant frustration and prompting customers to seek more reliable and consistent service providers. Conversations often show increased annoyance and confusion.
#
# *   **Pattern C: Lack of Transparency and Poor Communication**
#     *   *Description:* Dissatisfaction arises when customers encounter unclear, overwhelming, or vague information regarding policies, terms, or service details. This includes confusing promotional language, a lack of upfront knowledge about fees, and complex documentation. Even when information is provided, if it doesn't fully clarify or address underlying concerns, it fails to mitigate dissatisfaction.
#     *   *Evidence:* "Unclear information are major factors leading to dissatisfaction" (Case 2). Customers "get lost in the terms just get overwhelmed" (Case 18) and find that "varied phrasing can sometimes backfire causing more confusion" (Case 22). Stricter "coverage limits" and "restrictive" conditions (Case 20) are common points of contention. Vague responses (Case 24) and promotions that "confused a lot of customers" (Case 19) contribute to negative experiences. The agent notes that "even with detailed explanations it often leads to no change in dissatisfaction" (Case 10), and "transparency provided hasn't resolved your dissatisfaction" (Case 26), indicating that clarity alone is not always sufficient.
#     *   *Effect:* This leads to customer confusion, unmet expectations, and a feeling of being misled, often resulting in a decision to switch providers.
#
# *   **Pattern D: Ineffective Customer Support and Unresolved Concerns**
#     *   *Description:* The quality of customer interaction plays a crucial role in satisfaction. Customers become dissatisfied when they experience long wait times, feel their concerns are dismissed or not fully understood, or perceive that loyalty programs and perks are ineffective in addressing their issues. A lack of empathetic acknowledgment or a feeling of being rushed further exacerbates negative sentiments.
#     *   *Evidence:* "Repeated holds... are major factors leading to dissatisfaction" (Case 2, 27). Customers feel their "frustrations were brushed off" (Case 11) and that "quicker acknowledgment of issues can sometimes leave customers feeling rushed which might increase the perception of dissatisfaction" (Case 6). Loyalty programs are often perceived as ineffective, with customers feeling "less valued" (Case 28, 29) and stating that "the past dissatisfaction really weighs on me" (Case 9). Customers also express needing to "push to get anyone to understand what I meant" (Case 19).
#     *   *Effect:* This leads to heightened frustration, a sense of being unheard, and a significant decrease in loyalty, often pushing customers towards competitors.
#
# **3. Counterfactual Recommendation**
#
# *   *Observation:* We observed that when customers encounter issues related to pricing, service reliability, unclear communication, or unsupportive interactions, their dissatisfaction often leads to considering or actively pursuing alternative providers. The causal analysis, while descriptive, consistently shows the presence of negative emotions like annoyance, sadness, and confusion in these conversations, indicating underlying dissatisfaction.
# *   *Hypothesis:* If agents were empowered and trained to proactively address potential dissatisfaction points by:
#     1.  **Clearly communicating all pricing, fees, and promotional terms upfront**, ensuring customers understand the full value proposition and any limitations.
#     2.  **Providing transparent and realistic expectations regarding service quality and reliability**, and offering immediate, tangible solutions for service disruptions or delays.
#     3.  **Actively listening to and empathetically acknowledging customer concerns**, ensuring they feel heard and valued, and following through with effective resolutions rather than dismissive responses.
#     4.  **Streamlining complex processes and policies**, and ensuring loyalty programs offer genuinely valuable and relevant benefits that address past dissatisfaction.
#     We expect a significant reduction in customer frustration, an increase in perceived value, and improved customer retention, thereby mitigating the main reasons for dissatisfaction.
#
# **4. Citations**
#
# *   Case 1: 8646d0c8-3c73-406a-85c9-1f190be0342a
# *   Case 2: f83cd9ff-0bad-4d3c-a0ec-b66ff586faa0
# *   Case 3: 323a297d-2b51-4768-8330-71fe5f49a303
# *   Case 4: 0b335e64-038a-4ce1-9bf9-5c7f6de296d1
# *   Case 5: 323a297d-2b51-4768-8330-71fe5f49a303
# *   Case 6: 9f68956e-b8a6-4e37-9486-c94e41b87824
# *   Case 7: 4f790eae-bd55-4f81-9932-cc95f8163e09
# *   Case 8: ecace59b-026f-4b00-bfe1-2bbb9d8ad1d8
# *   Case 9: 2381d161-9941-45b6-8a88-1c7782109175
# *   Case 10: 1e39e3dc-3a93-44b4-b561-332e86c4186c
# *   Case 11: e98c51a4-e396-498b-b754-48f0ad973819
# *   Case 12: 20b65c41-db2b-458b-b6b2-489ff889294d
# *   Case 13: 05b57661-d858-43b5-a4c7-d6f719acb68c
# *   Case 14: 1d672a15-2b48-4bb8-a2ee-f57d6e09800d
# *   Case 15: e1e8889c-fa72-48e1-9360-822b8c5f3903
# *   Case 16: d33a0eac-98df-4849-bd8a-ff898b37c717
# *   Case 17: 298de186-e74b-4f0c-b59b-23c1beaa629e
# *   Case 18: 3efcb3bc-da76-4ccd-abd0-c8d2dc15509a
# *   Case 19: a7a56525-082b-4885-a611-54972ca31bce
# *   Case 20: 31a38350-0f9b-44d0-8652-9fbe94e901c0
# *   Case 21: b871d091-388c-4292-b963-ccf1e6beb3ad
# *   Case 22: d580d734-4d76-4988-af4d-6d70aeb1f829
# *   Case 23: d998269a-f5da-41c1-a7c9-7d9173001212
# *   Case 24: 1e323200-9c5f-4fb4-a30f-d1e6478f7df9
# *   Case 25: 7a7dd000-853a-4525-81c9-2af6a3320e34
# *   Case 26: 58d01e7a-3b9b-4a41-9ee5-de60db062588
# *   Case 27: 3010f32e-ae02-4801-8de5-0e6f975186c4
# *   Case 28: 6218ed5f-bdb7-4b3b-8380-1c7d3f93b5fa
# *   Case 29: 6218ed5f-bdb7-4b3b-8380-1c7d3f93b5fa
# *   Case 30: 1f289ffe-74f9-4ff0-b7b5-baddc1b86d36
# *   Case 31: 963c9168-5351-4f90-9c44-449bd73d4440
# *   Case 32: d7ebc2ce-024a-4dfa-982c-efb903c35905
# *   Case 33: 949833e3-ad0c-4450-afe1-b0d05dbe89f4
# *   Case 34: b5947e8a-5b0f-4338-b02c-d7803bf72ea2
# *   Case 35: fcf6bf5c-9088-44c8-ba8d-c6f450ad7746
# *   Case 36: fead89a0-a8b4-49aa-b6ed-cf7672d643b6
# *   Case 37: 20b65c41-db2b-458b-b6b2-489ff889294d

# %%
# 2. Follow-up Query (Should trigger 'memory_only' or 'hybrid' and use fewer rewrites)
query2 = "How could it have been avoided?"
print(f"\n--- Turn 2: {query2} ---")
result2 = agent.invoke(query2)
print(f"Response Length: {len(result2['response'])}")
print(f"Iterations: {result2['iterations']}")

# Check internal memory store
print("\n--- Internal Memory State ---")
memories = agent.memory.all()
print(f"Total Memories: {len(memories)}")
if memories:
    print(f"Last Memory Summary: {memories[-1].summary}")
# Out:
# --- Turn 2: How could it have been avoided? ---
# 2025-12-05 07:04:32,211 - src.rag.agentic_graph - INFO - Rewrites generated: 2
# 2025-12-05 07:04:32,211 - src.rag.agentic_graph - INFO - Memory candidates: 1
# 2025-12-05 07:04:32,211 - src.rag.agentic_graph - INFO - Memory routing decision: retrieve (selected 0 memories)
# 2025-12-05 07:04:32,211 - src.rag.agentic_graph - INFO - Running full dual retrieval (retrieve) on 2 queries.
# 2025-12-05 07:04:32,211 - src.rag.agentic_graph - INFO - Memory candidates: 1
# 2025-12-05 07:04:32,211 - src.rag.agentic_graph - INFO - Memory routing decision: retrieve (selected 0 memories)
# 2025-12-05 07:04:32,211 - src.rag.agentic_graph - INFO - Running full dual retrieval (retrieve) on 2 queries.
# Rewritten queries:
#
# - How could customer dissatisfaction have been avoided?
# - What actions prevent customer churn?
# Classified Intent: Investigate_Complaint
# Classified Intent: Investigate_Complaint
# Classified Intent: Inquire_About_Retention_Offers
# Classified Intent: Inquire_About_Retention_Offers
# 2025-12-05 07:04:50,535 - src.rag.retriever - INFO - Batch reranking 100 pairs across 2 queries...
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# 2025-12-05 07:04:54,742 - src.rag.agentic_graph - INFO - Retrieved 20 docs
# 2025-12-05 07:04:54,745 - src.rag.agentic_graph - INFO - ---GENERATE CAUSAL ANALYSIS---
# 2025-12-05 07:04:54,745 - src.rag.agentic_graph - INFO - ---GENERATE CAUSAL ANALYSIS---
# 2025-12-05 07:05:38,057 - src.rag.agentic_graph - INFO - Generation complete.
# 2025-12-05 07:05:38,057 - src.rag.agentic_graph - INFO - ---CRITIQUE ANSWER---
# 2025-12-05 07:05:38,057 - src.rag.agentic_graph - INFO - Generation complete.
# 2025-12-05 07:05:38,057 - src.rag.agentic_graph - INFO - ---CRITIQUE ANSWER---
# 2025-12-05 07:05:45,526 - src.rag.agentic_graph - INFO - Critique pass=True; failed_checks=[]; reason=
# 2025-12-05 07:05:45,540 - src.rag.agentic_graph - INFO - ---SUMMARY GENERATION & MEM STORE---
# 2025-12-05 07:05:45,526 - src.rag.agentic_graph - INFO - Critique pass=True; failed_checks=[]; reason=
# 2025-12-05 07:05:45,540 - src.rag.agentic_graph - INFO - ---SUMMARY GENERATION & MEM STORE---
# 2025-12-05 07:05:49,108 - src.rag.agentic_graph - INFO - Stored MemoryEntry id=03593e96ee with 20 docs.
# 2025-12-05 07:05:49,108 - src.rag.agentic_graph - INFO - ----- REQUEST FLOW SUMMARY -----
# 2025-12-05 07:05:49,108 - src.rag.agentic_graph - INFO - Final generation length: 6393 chars
# 2025-12-05 07:05:49,123 - src.rag.agentic_graph - INFO - Critique pass: True
# 2025-12-05 07:05:49,125 - src.rag.agentic_graph - INFO - Critique reason:
# 2025-12-05 07:05:49,125 - src.rag.agentic_graph - INFO - Memory stored: 2
# 2025-12-05 07:05:49,125 - src.rag.agentic_graph - INFO - Routing: retrieve
# 2025-12-05 07:05:49,108 - src.rag.agentic_graph - INFO - Stored MemoryEntry id=03593e96ee with 20 docs.
# 2025-12-05 07:05:49,108 - src.rag.agentic_graph - INFO - ----- REQUEST FLOW SUMMARY -----
# 2025-12-05 07:05:49,108 - src.rag.agentic_graph - INFO - Final generation length: 6393 chars
# 2025-12-05 07:05:49,123 - src.rag.agentic_graph - INFO - Critique pass: True
# 2025-12-05 07:05:49,125 - src.rag.agentic_graph - INFO - Critique reason:
# 2025-12-05 07:05:49,125 - src.rag.agentic_graph - INFO - Memory stored: 2
# 2025-12-05 07:05:49,125 - src.rag.agentic_graph - INFO - Routing: retrieve
# 2025-12-05 07:05:49,125 - src.rag.agentic_graph - INFO - Used rewrites count: 2
# 2025-12-05 07:05:49,125 - src.rag.agentic_graph - INFO - Used rewrites count: 2
# Response Length: 6393
# Iterations: 1
#
# --- Internal Memory State ---
# Total Memories: 2
# Last Memory Summary: Customer dissatisfaction and churn are primarily driven by systemic service failures and a perceived lack of value, not merely a lack of emotional support. While agent empathy can mitigate immediate negative emotions, it often fails to improve overall customer sentiment when core issues like denied claims or service outages remain unresolved. To effectively reduce churn, agents must move beyond superficial emotional interventions to proactively identify, escalate, and resolve systemic problems,

# %%
print(result2['response'])
# Out:
# **1. Executive Summary**
#
# The primary driver of customer dissatisfaction and churn risk, which could have been avoided, stems from systemic service failures and a perceived lack of genuine value or acknowledgment, rather than solely from a lack of emotional support. While agents' efforts to reduce negative emotions and express approval are effective in mitigating immediate emotional distress, these interventions often fail to significantly improve overall customer sentiment when core issues like denied claims, service outages, unclear policies, or ineffective loyalty programs remain unresolved. Customers frequently express feeling undervalued by generic solutions or a lack of proactive, reliable follow-up, indicating that a deeper, more structural approach to problem resolution and value demonstration is necessary to prevent negative outcomes.
#
# **2. Key Causal Patterns**
#
# *   **Pattern A: Systemic Service Failures Undermine Emotional Support.**
#     *   *Evidence:* Customers consistently voice frustration over fundamental service issues such as denied claims (Case 1), unclear information and repeated holds (Case 2), persistent service outages (Case 3, 17), promotions that worsen expectations or feel misleading (Case 4, 5, 8, 18), ineffective loyalty program perks (Case 6, 9, 10), and a general lack of transparency regarding policy details (Case 11).
#     *   *Effect:* The causal analysis shows that while interventions aimed at significantly reducing negative emotions (sadness, anger, and annoyance) and increasing approval were effective in lowering these specific emotional states, they often resulted in only a modest improvement, or even a slight decline, in overall customer sentiment. For instance, several cases (e.g., Case 323a297d-2b51-4768-8330-71fe5f49a303, 2aa8d803-eeb4-4669-b55c-3613d09c050d, afab6262-bf73-4ea0-a163-7f2c21405111, ca99cdb9-5429-4d18-bb2a-bed36b625a55) showed a negligible or negative shift in sentiment despite strong emotional interventions. This indicates that addressing the core service issues is paramount, as emotional management alone cannot fully resolve deep-seated dissatisfaction.
#
# *   **Pattern B: Perceived Lack of Value and Acknowledgment Fuels Churn Risk.**
#     *   *Evidence:* Customers explicitly state they need to feel their concerns are "listened to" (Case 5), express feeling "less valued" by generic loyalty offerings (Case 6, 9), perceive promotions as merely "upsell options" (Case 10), and emphasize that service "has to improve first" before considering retention options (Case 15). They also highlight that things "won't feel that way if things don't change" (Case 18) and that their requests are not being "acknowledged" (Case 20).
#     *   *Effect:* The consistent and significant reduction in negative emotions (sadness, anger, and annoyance) observed in the causal analysis across nearly all cases demonstrates the immediate impact of empathetic and approving agent interactions. However, the recurring customer statements about feeling undervalued suggest that while immediate emotional distress can be mitigated, the underlying perception of value, if not addressed with substantive solutions, continues to drive churn risk. Cases like 2381d161-9941-45b6-8a88-1c7782109175, which showed only a small positive sentiment shift despite strong emotional interventions, highlight this gap.
#
# *   **Pattern C: Insufficient Follow-up and Proactive Resolution.**
#     *   *Evidence:* Customers frequently request to be "kept in the loop" (Case 3), inquire about what can be done to "prevent that" (churn) and are told tickets will be "prioritized and follow up regularly" (Case 17), and ask for confirmation of follow-up actions (Case 20). The implication is that current processes lack sufficient proactive communication and reliable resolution paths.
#     *   *Effect:* The causal analysis shows that interventions to reduce negative emotions and increase approval generally lead to positive shifts in sentiment. However, the frequent customer requests for follow-up and prioritization indicate that even when immediate emotional states are improved, the lack of a clear, reliable path to resolution and proactive communication leaves customers uncertain and vulnerable to future dissatisfaction, thus failing to fully prevent the negative outcome.
#
# **3. Counterfactual Recommendation**
#
# *   *Observation:* We observed that when agents primarily focused on emotional management and offering standard retention options (like loyalty perks or discounts) without addressing the underlying systemic service failures or the customer's perceived lack of value, customer sentiment often showed minimal improvement or even a slight decline, despite a reduction in immediate negative emotions.
# *   *Hypothesis:* If agents were empowered and trained to not only provide empathetic support but also to proactively identify, escalate, and ensure resolution of systemic service issues, and to offer personalized, value-driven solutions supported by clear, reliable follow-up mechanisms, we expect a significant and sustained improvement in customer sentiment and a substantial reduction in churn risk. This would involve moving beyond superficial emotional interventions to tackle the root causes of dissatisfaction.
#
# **4. Citations**
#
# Case 1: 8646d0c8-3c73-406a-85c9-1f190be0342a
# Case 2: f83cd9ff-0bad-4d3c-a0ec-b66ff586faa0
# Case 3: 4f790eae-bd55-4f81-9932-cc95f8163e09
# Case 4: 323a297d-2b51-4768-8330-71fe5f49a303
# Case 5: 9f68956e-b8a6-4e37-9486-c94e41b87824
# Case 6: 6218ed5f-bdb7-4b3b-8380-1c7d3f93b5fa
# Case 7: 26a4aebe-5a1f-4f26-bd2c-d44aacb70176
# Case 8: 323a297d-2b51-4768-8330-71fe5f49a303 (Duplicate ID, but distinct segment in input)
# Case 9: 6218ed5f-bdb7-4b3b-8380-1c7d3f93b5fa (Duplicate ID, but distinct segment in input)
# Case 10: 2381d161-9941-45b6-8a88-1c7782109175
# Case 11: 2aa8d803-eeb4-4669-b55c-3613d09c050d
# Case 12: a6736a96-1360-4f96-b0ce-55b638dc0357
# Case 13: afab6262-bf73-4ea0-a163-7f2c21405111
# Case 14: a6736a96-1360-4f96-b0ce-55b638dc0357 (Duplicate ID, but distinct segment in input)
# Case 15: 3af88840-246e-45e0-91c5-992b4cfd6505
# Case 16: afab6262-bf73-4ea0-a163-7f2c21405111 (Duplicate ID, but distinct segment in input)
# Case 17: 90f36fa3-270d-419a-bb7c-2f99a5cb3d2b
# Case 18: 2c73b893-976b-43b1-9d82-b3fb62fa1af0
# Case 19: ca99cdb9-5429-4d18-bb2a-bed36b625a55
# Case 20: d81fafda-ac2b-4571-8cdb-7a582b224498
